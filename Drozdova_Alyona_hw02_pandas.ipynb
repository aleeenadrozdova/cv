# %% [markdown]
# # Домашнее задание 2 (5 баллов).
#
# Все задания ниже имеют равный вес (5/16).

# %%
import pandas as pd
import os

# !wget https://github.com/hse-ds/iad-intro-ds/raw/master/2023/homeworks/Data.zip
# !unzip /content/Data.zip

# %% [markdown]
# #### Описание данных
#
# В папке Dat (https://github.com/hse-ds/iad-intro-ds/blob/master/2023/homeworks/Data.zip) находится информация о студентах. Всего 10 групп студентов. Файлы делятся на две категории:
#     * Students_info_i - информация о студентах из группы i
#     * Students_marks_i - оценки студентов из группы i за экзамены

# %% [markdown]
# ### Одно из важных достоинств pandas $-$ это удобные методы реляционного взаимодействия с данными, аналогичные, например, возможностям SQL для слияния и конкатенации таблиц: merge, join, concat. Наличие готовых методов позволяет не реализовывать самостоятельно поэлементную обработку данных и оперировать сразу целыми таблицами данных.
#
# Подробно об этих методах посмотрите тут: https://www.kaggle.com/residentmario/renaming-and-combining#Combining

# %% [markdown]
# #### Задание 1. Соберите всю информацию о студентах в одну таблицу df. В получившейся таблице должна быть информация и оценки всех студентов из всех групп. Напечатайте несколько строк таблицы для демонстрации результата.¶

# %%
marks = pd.DataFrame()
students = pd.DataFrame()

data_folder = '/content/Data'

files = os.listdir(data_folder)

for file in files:
    if file.startswith('Students_info_'):
        file_path = os.path.join(data_folder, file)
        file_df = pd.read_csv(file_path)
        students = pd.concat([students, file_df])
    if file.startswith('Students_marks_'):
        file_path = os.path.join(data_folder, file)
        file_df = pd.read_csv(file_path)
        marks = pd.concat([marks, file_df])


df = pd.merge(students, marks, on='index')
df.head()
# Out:
#    index  gender race/ethnicity parental level of education         lunch  \
# 0    200  female        group C          associate's degree      standard
# 1    201  female        group D                some college  free/reduced
# 2    202    male        group C          associate's degree      standard
# 3    203  female        group B          associate's degree      standard
# 4    204    male        group C                some college      standard
#
#   test preparation course   group  math score  reading score  writing score
# 0               completed  group3          67             84             86
# 1                    none  group3          65             81             77
# 2                    none  group3          69             77             69
# 3                    none  group3          57             69             68
# 4                    none  group3          59             41             42

# %% [markdown]
# #### Задание 2. Удалите столбец index у полученной таблицы. Напечатайте первые 10 строк таблицы.

# %%
df = df.drop(columns='index')
df[:10]
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group C          associate's degree      standard
# 1  female        group D                some college  free/reduced
# 2    male        group C          associate's degree      standard
# 3  female        group B          associate's degree      standard
# 4    male        group C                some college      standard
# 5    male        group D            some high school      standard
# 6    male        group E           bachelor's degree      standard
# 7    male        group E                 high school      standard
# 8  female        group B                some college  free/reduced
# 9  female        group B                some college  free/reduced
#
#   test preparation course   group  math score  reading score  writing score
# 0               completed  group3          67             84             86
# 1                    none  group3          65             81             77
# ...

# %% [markdown]
# #### Задание 3. Выведите на экран размеры полученной таблицы

# %%
df.shape
# Out:
# (1000, 9)

# %% [markdown]
# #### Задание 4. Выведите на экран статистические характеристики числовых столбцов таблицы (минимум, максимум, среднее значение, стандартное отклонение)

# %%
df.describe().loc[['min', 'max', 'mean', 'std']]
# Out:
#       math score  reading score  writing score
# min      0.00000      17.000000      10.000000
# max    100.00000     100.000000     100.000000
# mean    66.08900      69.169000      68.054000
# std     15.16308      14.600192      15.195657

# %% [markdown]
# #### Задание 5. Проверьте, есть ли в таблице пропущенные значения

# %%
df.isnull().sum()
# Out:
# gender                         0
# race/ethnicity                 0
# parental level of education    0
# lunch                          0
# test preparation course        0
# group                          0
# math score                     0
# reading score                  0
# writing score                  0
# dtype: int64

# %% [markdown]
# #### Задание 6. Выведите на экран средние баллы студентов по каждому предмету (math, reading, writing)

# %%
print(f'''Math: {df['math score'].mean()}''')
print(f'''Reading: {df['reading score'].mean()}''')
print(f'''Writing: {df['writing score'].mean()}''')
# Out:
# Math: 66.089
# Reading: 69.169
# Writing: 68.054

# %% [markdown]
# **Задание 7. Как зависят оценки от того, проходил ли студент курс для подготовки к сдаче экзамена (test preparation course)? Выведите на экран для каждого предмета в отдельности средний балл студентов, проходивших курс для подготовки к экзамену и не проходивших курс.**

# %%
df.groupby('test preparation course')[['math score', 'reading score', 'writing score']].mean()
# Out:
#                          math score  reading score  writing score
# test preparation course
# completed                 69.695531      73.893855      74.418994
# none                      64.077882      66.534268      64.504673

# %% [markdown]
# **Задание 8. Выведите на экран все различные значения из столбца lunch.**

# %%
df.lunch.drop_duplicates()
# Out:
# 0        standard
# 1    free/reduced
# Name: lunch, dtype: object

# %% [markdown]
# **Задание 9. Переименуйте колонку "parental level of education" в "education", а "test preparation course" в "test preparation" с помощью метода pandas rename**
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.rename.html

# %%
df.rename(columns={'parental level of education':'education', 'test preparation course':'test preparation'}, inplace=True)
df.head()
# Out:
#    gender race/ethnicity           education         lunch test preparation  \
# 0  female        group C  associate's degree      standard        completed
# 1  female        group D        some college  free/reduced             none
# 2    male        group C  associate's degree      standard             none
# 3  female        group B  associate's degree      standard             none
# 4    male        group C        some college      standard             none
#
#     group  math score  reading score  writing score
# 0  group3          67             84             86
# 1  group3          65             81             77
# 2  group3          69             77             69
# 3  group3          57             69             68
# 4  group3          59             41             42

# %% [markdown]
# **Зафиксируем минимальный балл для сдачи экзамена**

# %%
passmark = 50

# %% [markdown]
# **Задание 10. Ответьте на вопросы:**
#     * Какая доля студентов сдала экзамен по математике (passmark >= 50)?
#     * Какая доля студентов, проходивших курс подготовки к экзамену, сдала экзамен по математике?
#     * Какая доля женщин, не проходивших курс подготовки к экзамену, не сдала экзамен по математике?

# %%
# df['math score'] = df['math score'].astype(int)
print(f'''Какая доля студентов сдала экзамен по математике?  {len(df[df['math score'] >= passmark])/len(df)}''')
print(f'''Какая доля студентов, проходивших курс подготовки к экзамену, сдала экзамен по математике?  {len(df[(df['math score'] >= passmark)&(df['test preparation']=='completed')])/len(df[df['test preparation']=='completed'])}''')
print(f'''Какая доля женщин, не проходивших курс подготовки к экзамену, не сдала экзамен по математике?  {len(df[(df['math score'] < passmark)&(df['test preparation']!='completed')&(df.gender=='female')])/len(df[(df['test preparation']!='completed')&(df.gender=='female')])}''')
# Out:
# Какая доля студентов сдала экзамен по математике?  0.865
# Какая доля студентов, проходивших курс подготовки к экзамену, сдала экзамен по математике?  0.9217877094972067
# Какая доля женщин, не проходивших курс подготовки к экзамену, не сдала экзамен по математике?  0.20958083832335328

# %% [markdown]
# **Задание 11. С помощью groupby выполните задания ниже. Также выведите время выполнения каждого из заданий.**
#     * Для каждой этнической группы выведите средний балл за экзамен по чтению
#     * Для каждого уровня образования выведите минимальный балл за экзамен по письму

# %%
# %%time
df.groupby('race/ethnicity')[['reading score']].mean()
# Out:
# CPU times: user 3.14 ms, sys: 853 µs, total: 4 ms
# Wall time: 3.91 ms
#                 reading score
# race/ethnicity
# group A             64.674157
# group B             67.352632
# group C             69.103448
# group D             70.030534
# group E             73.028571

# %%
# %%time
df.groupby('education')[['writing score']].min()
# Out:
# CPU times: user 3.47 ms, sys: 0 ns, total: 3.47 ms
# Wall time: 3.48 ms
#                     writing score
# education
# associate's degree             35
# bachelor's degree              38
# high school                    15
# master's degree                46
# some college                   19
# some high school               10

# %% [markdown]
# **Задание 12. Выполните задание 11 с помощью циклов. Сравните время выполнения.**

# %%
# %%time

for group in df['race/ethnicity'].unique():
    print(f'''Средний балл за чтение для {group}: {df[df['race/ethnicity'] == group]['reading score'].mean()}''')
# Out:
# Средний балл за чтение для group C: 69.10344827586206
# Средний балл за чтение для group D: 70.03053435114504
# Средний балл за чтение для group B: 67.35263157894737
# Средний балл за чтение для group E: 73.02857142857142
# Средний балл за чтение для group A: 64.67415730337079
# CPU times: user 6.12 ms, sys: 26 µs, total: 6.15 ms
# Wall time: 8.33 ms

# %%
# %%time

for group in df['education'].unique():
    print(f'''Средний балл за чтение для {group}: {df[df['education'] == group]['reading score'].min()}''')
# Out:
# Средний балл за чтение для associate's degree: 31
# Средний балл за чтение для some college: 23
# Средний балл за чтение для some high school: 17
# Средний балл за чтение для bachelor's degree: 41
# Средний балл за чтение для high school: 24
# Средний балл за чтение для master's degree: 42
# CPU times: user 6.29 ms, sys: 55 µs, total: 6.35 ms
# Wall time: 6.81 ms

# %% [markdown]
# **Задание 13. Выведите на экран средние баллы студентов по каждому предмету в зависимости от пола и уровня образования. То есть должно получиться количество групп, равных 2 * (число уровней образования), и для каждой такой группы выыведите средний балл по каждому из предметов.**
#
# Это можно сделать с помощью сводных таблиц (pivot_table):
#
# https://www.kaggle.com/kamilpolak/tutorial-how-to-use-pivot-table-in-pandas

# %%
import numpy as np
pd.pivot_table(df, index=['gender', 'education'], values=['math score', 'reading score', 'writing score'], aggfunc=np.mean)
# Out:
#                            math score  reading score  writing score
# gender education
# female associate's degree   65.250000      74.120690      74.000000
#        bachelor's degree    68.349206      77.285714      78.380952
#        high school          59.351064      68.202128      66.691489
#        master's degree      66.500000      76.805556      77.638889
#        some college         65.406780      73.550847      74.050847
#        some high school     59.296703      69.109890      68.285714
# male   associate's degree   70.764151      67.433962      65.405660
#        bachelor's degree    70.581818      68.090909      67.654545
#        high school          64.705882      61.480392      58.539216
#        master's degree      74.826087      73.130435      72.608696
#        some college         69.009259      64.990741      63.148148
#        some high school     67.840909      64.693182      61.375000

# %% [markdown]
# #### Задание 14. Сколько студентов успешно сдали экзамен по математике?
#
# Создайте новый столбец в таблице df под названием Math_PassStatus и запишите в него F, если студент не сдал экзамен по математике (балл за экзамен < passmark), и P иначе.
#
# Посчитайте количество студентов, сдавших и не сдавших экзамен по математике.
#
# Сделайте аналогичные шаги для экзаменов по чтению и письму.

# %%
df['Math_PassStatus'] = df['math score'].apply(lambda x: 'P' if x >= passmark else 'F')
df.head()
# Out:
#    gender race/ethnicity           education         lunch test preparation  \
# 0  female        group C  associate's degree      standard        completed
# 1  female        group D        some college  free/reduced             none
# 2    male        group C  associate's degree      standard             none
# 3  female        group B  associate's degree      standard             none
# 4    male        group C        some college      standard             none
#
#     group  math score  reading score  writing score Math_PassStatus
# 0  group3          67             84             86               P
# 1  group3          65             81             77               P
# 2  group3          69             77             69               P
# 3  group3          57             69             68               P
# 4  group3          59             41             42               P

# %%
df['Math_PassStatus'].value_counts()
# Out:
# P    865
# F    135
# Name: Math_PassStatus, dtype: int64

# %%
df['Reading_PassStatus'] = df['reading score'].apply(lambda x: 'P' if x >= passmark else 'F')
df['Reading_PassStatus'].value_counts()
# Out:
# P    910
# F     90
# Name: Reading_PassStatus, dtype: int64

# %%
df['Writing_PassStatus'] = df['writing score'].apply(lambda x: 'P' if x >= passmark else 'F')
df['Writing_PassStatus'].value_counts()
# Out:
# P    886
# F    114
# Name: Writing_PassStatus, dtype: int64

# %% [markdown]
# #### Задание 15. Сколько студентов успешно сдали все экзамены?
#
# Создайте столбец OverAll_PassStatus и запишите в него для каждого студента 'F', если студент не сдал хотя бы один из трех экзаменов, а иначе 'P'.
#
# Посчитайте количество студентов, которые сдали все экзамены.

# %%
df['Overall_PassStatus'] = df.apply(lambda x: 'F' if 'F' in x[['Math_PassStatus', 'Reading_PassStatus', 'Writing_PassStatus']].to_list() else 'P', axis=1)
df.head()
# Out:
#    gender race/ethnicity           education         lunch test preparation  \
# 0  female        group C  associate's degree      standard        completed
# 1  female        group D        some college  free/reduced             none
# 2    male        group C  associate's degree      standard             none
# 3  female        group B  associate's degree      standard             none
# 4    male        group C        some college      standard             none
#
#     group  math score  reading score  writing score Math_PassStatus  \
# 0  group3          67             84             86               P
# 1  group3          65             81             77               P
# 2  group3          69             77             69               P
# 3  group3          57             69             68               P
# 4  group3          59             41             42               P
#
#   Reading_PassStatus Writing_PassStatus Overall_PassStatus
# ...

# %%
df['Overall_PassStatus'].value_counts()
# Out:
# P    812
# F    188
# Name: Overall_PassStatus, dtype: int64

# %% [markdown]
# #### Задание 16. Переведем баллы в оценки
#
# ### Система перевода баллов в оценки
# ####    больше 90 = A
# ####      80-90 = B
# ####      70-80 = C
# ####      60-70 = D
# ####      50-60 = E
# ####    меньше 50 = F (Fail)
#
# Создайте вспомогательную функцию, которая будет по среднему баллу за три экзамена выставлять оценку студенту по данным выше критериям.
#
# Создайте столбец Grade и запишите в него оценку каждого студента.
#
# Выведите количество студентов, получивших каждую из оценок.
#
# **В случае, если средний балл попадает на границу между оценками (т.е. равен ровно 60, 70 или 80 баллов), вы можете интерпретировать условие на своё усмотрение (т.е. можете поставить за 60 баллов оценку D, а можете - E).**

# %%
def GetGrade(average_mark):
    if average_mark > 90:
        return 'A'
    elif average_mark > 80:
        return 'B'
    elif average_mark > 70:
        return 'C'
    elif average_mark > 60:
        return 'D'
    elif average_mark >= 50:
        return 'E'
    else:
        return 'F (Fail)'

df['Grade'] = df.apply(lambda x: GetGrade(np.mean(x[['math score', 'reading score', 'writing score']])), axis=1)
df.head()
# Out:
#    gender race/ethnicity           education         lunch test preparation  \
# 0  female        group C  associate's degree      standard        completed
# 1  female        group D        some college  free/reduced             none
# 2    male        group C  associate's degree      standard             none
# 3  female        group B  associate's degree      standard             none
# 4    male        group C        some college      standard             none
#
#     group  math score  reading score  writing score Math_PassStatus  \
# 0  group3          67             84             86               P
# 1  group3          65             81             77               P
# 2  group3          69             77             69               P
# 3  group3          57             69             68               P
# 4  group3          59             41             42               P
#
#   Reading_PassStatus Writing_PassStatus Overall_PassStatus     Grade
# ...

# %%
df['Grade'].value_counts()
# Out:
# D           260
# C           253
# E           190
# B           144
# F (Fail)    103
# A            50
# Name: Grade, dtype: int64
